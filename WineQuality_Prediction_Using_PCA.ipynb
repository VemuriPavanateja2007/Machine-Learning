# %% [markdown]
# <a href="https://colab.research.google.com/github/VemuriPavanateja2007/Machine-Learning/blob/main/WineQuality_Prediction_Using_PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
data=pd.read_csv("WineQT.csv")
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
X=data.drop('quality',axis=1)
y=data['quality']

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
pca=PCA(n_components=3)
x_pca=pca.fit_transform(X_scaled)

# %%
print("EXPLAINED VARIANCE RATIO:",pca.explained_variance_ratio_)
print("TOTAL VARIANCE RATIO:",sum(pca.explained_variance_ratio_))
# Out:
# EXPLAINED VARIANCE RATIO: [0.27194409 0.15872089 0.13585374]
# TOTAL VARIANCE RATIO: 0.5665187172585151

# %%
plt.figure()
plt.scatter(x_pca[:,0],x_pca[:,1],c=y)
plt.xlabel('principal component 1')
plt.ylabel('principal component 2')
plt.title('principal compnent analysis')
plt.show()
